# %%
from joblib import dump, load
import numpy as np
model= load('Dragon.joblib')

# %%
input = np.array([[-0.44241248,  3.18716752, -1.12581552, -0.27288841, -1.42038605,
       -0.55321154, -1.7412613 ,  2.56284386, -0.99534776, -0.57387797,
       -0.99428207,  0.43852974, -0.49833679]])
model.predict(input)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 input = array([[-0.44241248,  3.18716752, -1.12581552, -0.27288841, -1.42038605,
#       2        -0.55321154, -1.7412613 ,  2.56284386, -0.99534776, -0.57387797,
#       3        -0.99428207,  0.43852974, -0.49833679]])
#       4 model.predict(input)
#
# NameError: name 'array' is not defined
